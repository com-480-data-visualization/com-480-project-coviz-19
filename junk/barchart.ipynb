# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../data/I1.csv")

# %%
data.head()
# Out:
#   Div        Date   Time    HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  I1  24/08/2019  17:00       Parma  Juventus     0     1   A     0     1
# 1  I1  24/08/2019  19:45  Fiorentina    Napoli     3     4   A     1     2
# 2  I1  25/08/2019  17:00     Udinese     Milan     1     0   H     0     0
# 3  I1  25/08/2019  19:45    Cagliari   Brescia     0     1   A     0     0
# 4  I1  25/08/2019  19:45        Roma     Genoa     3     3   D     2     2
#
#    ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0  ...     2.15  1.50      1.77      2.02   1.81   2.11     1.93     2.12
# 1  ...     2.15  0.75      1.75      2.05   1.81   2.11     1.94     2.14
# 2  ...     1.78  0.50      1.86      2.07   1.88   2.04     1.91     2.09
# 3  ...     1.83 -0.75      2.10      1.83   2.11   1.82     2.12     1.85
# 4  ...     2.23 -0.75      1.97      1.96   1.98   1.94     1.99     2.20
#
#    AvgCAHH  AvgCAHA
# 0     1.83     2.04
# 1     1.80     2.09
# ...

# %%
data = data[["HomeTeam", "AwayTeam", "FTR", "B365H", "B365D", "B365A"]]

# %%
data
# Out:
#        HomeTeam    AwayTeam FTR  B365H  B365D  B365A
# 0         Parma    Juventus   A   9.00   5.25   1.33
# 1    Fiorentina      Napoli   A   4.75   3.75   1.72
# 2       Udinese       Milan   H   3.75   3.30   2.05
# 3      Cagliari     Brescia   A   1.83   3.60   4.33
# 4          Roma       Genoa   D   1.45   4.20   8.00
# ..          ...         ...  ..    ...    ...    ...
# 251       Milan       Genoa   A   1.66   3.80   5.25
# 252   Sampdoria      Verona   H   2.60   3.20   2.80
# 253     Udinese  Fiorentina   D   2.90   3.25   2.50
# 254    Juventus       Inter   H   2.25   3.30   3.30
# 255    Sassuolo     Brescia   H   1.75   3.75   4.50
#
# [256 rows x 6 columns]

# %%
team_results = {}

# %%
def find_results(row):
    global team_results
    home = row["HomeTeam"]
    away = row["AwayTeam"]
    res = row["FTR"]
    oddsH = row["B365H"]
    oddsD = row["B365D"]
    oddsA = row["B365A"]
    
    if not home in team_results:
        team_results[home] = 0
    
    if not away in team_results:
        team_results[away] = 0
        
    pred = np.array([oddsH, oddsD, oddsA]).argmin()
    
    pred = np.array(["H", "D", "A"])[pred]
    
    if res == pred:
        team_results[home] += 1
        team_results[away] += 1

# %%
data.apply(find_results, axis = 1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 251    None
# 252    None
# 253    None
# 254    None
# 255    None
# Length: 256, dtype: object

# %%
team_results
# Out:
# {'Parma': 11,
#  'Juventus': 18,
#  'Fiorentina': 11,
#  'Napoli': 12,
#  'Udinese': 13,
#  'Milan': 17,
#  'Cagliari': 10,
#  'Brescia': 18,
#  'Roma': 14,
#  'Genoa': 13,
#  'Sampdoria': 16,
#  'Lazio': 18,
#  'Spal': 15,
#  'Atalanta': 13,
#  'Torino': 13,
#  'Sassuolo': 15,
#  'Verona': 11,
#  'Bologna': 12,
#  'Inter': 17,
#  'Lecce': 13}

# %%
total = (len(team_results) - 1) * 2

# %%
total
# Out:
# 38

# %%
team_results = pd.DataFrame.from_dict(team_results, orient="index", columns=["pred"])

# %%
team_results["wrong_pred"]=total-team_results["pred"]

# %%
team_results["wrong_pred"]=team_results["wrong_pred"]-team_results["pred"]

# %%
team_results
# Out:
#             pred  wrong_pred
# Parma         11          27
# Juventus      18          20
# Fiorentina    11          27
# Napoli        12          26
# Udinese       13          25
# Milan         17          21
# Cagliari      10          28
# Brescia       18          20
# Roma          14          24
# Genoa         13          25
# Sampdoria     16          22
# Lazio         18          20
# Spal          15          23
# Atalanta      13          25
# Torino        13          25
# Sassuolo      15          23
# Verona        11          27
# Bologna       12          26
# Inter         17          21
# Lecce         13          25

# %%
team_results = team_results.sort_values("pred")

# %%
team_results["temp"] = range(1, len(team_results) + 1)

# %%
team_results = team_results.reset_index()

# %%
team_results
# Out:
#             pred  wrong_pred
# Cagliari      10          28
# Parma         11          27
# Fiorentina    11          27
# Verona        11          27
# Bologna       12          26
# Napoli        12          26
# Torino        13          25
# Atalanta      13          25
# Genoa         13          25
# Udinese       13          25
# Lecce         13          25
# Roma          14          24
# Spal          15          23
# Sassuolo      15          23
# Sampdoria     16          22
# Inter         17          21
# Milan         17          21
# Lazio         18          20
# Brescia       18          20
# Juventus      18          20

# %%
team_results = team_results.rename(columns={"index": "name", "temp" : "order"})

# %%
team_results
# Out:
#             pred  wrong_pred
# Cagliari      10          28
# Parma         11          27
# Fiorentina    11          27
# Verona        11          27
# Bologna       12          26
# Napoli        12          26
# Torino        13          25
# Atalanta      13          25
# Genoa         13          25
# Udinese       13          25
# Lecce         13          25
# Roma          14          24
# Spal          15          23
# Sassuolo      15          23
# Sampdoria     16          22
# Inter         17          21
# Milan         17          21
# Lazio         18          20
# Brescia       18          20
# Juventus      18          20

# %%
team_results.to_csv("barchart.csv", index=False)
